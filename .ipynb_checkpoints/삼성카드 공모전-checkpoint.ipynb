# %%
import pandas as pd

import re
import numpy as np

from pykospacing import spacing

# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
data = pd.read_excel('공모전_제공_데이터(1차).xlsx', sheet_name = '학습데이터')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   NO                    1000 non-null   int64
#  1   NO2                   1000 non-null   int64
#  2   발화                    1000 non-null   object
#  3   발화1                   1000 non-null   object
#  4   발화1의 우선순위             1000 non-null   int64
#  5   발화2                   32 non-null     object
#  6   발화2의 우선순위             32 non-null     float64
#  7   발화3                   3 non-null      object
#  8   발화3의 우선순위             3 non-null      float64
#  9   최종분류(우선순위 가장 높은것 선택)  1000 non-null   object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 78.2+ KB

# %%
data.head(5)
# Out:
#    NO    NO2                   발화             발화1  발화1의 우선순위  발화2  발화2의 우선순위  \
# 0   1   6438     상담직원과 빠른연결했슴좋겠어요  불만>고객서비스>상담시스템          5  NaN        NaN
# 1   2   6850    안기다리고. 빨리상담되었음좋겠다  불만>고객서비스>상담시스템          5  NaN        NaN
# 2   3   7294   너무 오래기다리고 상담이 늦어져요  불만>고객서비스>상담시스템          5  NaN        NaN
# 3   4   9484  상담직원과  통화가  매우  힘들다  불만>고객서비스>상담시스템          5  NaN        NaN
# 4   5  10350     상담받으려면오래기다리는게불편함  불만>고객서비스>상담시스템          5  NaN        NaN
#
#    발화3  발화3의 우선순위 최종분류(우선순위 가장 높은것 선택)
# 0  NaN        NaN       불만>고객서비스>상담시스템
# 1  NaN        NaN       불만>고객서비스>상담시스템
# 2  NaN        NaN       불만>고객서비스>상담시스템
# 3  NaN        NaN       불만>고객서비스>상담시스템
# 4  NaN        NaN       불만>고객서비스>상담시스템

# %%
data_rank = sorted(data['발화1의 우선순위'].unique())

# %%
rank = pd.read_excel('공모전_제공_데이터(1차).xlsx', sheet_name = '우선순위')

# %%
rank
# Out:
#     우선순위           의도명(유형)
# 0      1      칭찬>고객서비스>상담원
# 1      2    칭찬>고객서비스>상담시스템
# 2      3          칭찬>고객서비스
# 3      4      불만>고객서비스>상담원
# 4      5    불만>고객서비스>상담시스템
# 5      6          불만>고객서비스
# 6      7        칭찬>삼성카드>혜택
# 7      8    칭찬>삼성카드>할부금융상품
# 8      9   칭찬>삼성카드>커뮤니티서비스
# 9     10   칭찬>삼성카드>카드이용/결제
# 10    11      칭찬>삼성카드>카드상품
# 11    12      칭찬>삼성카드>청구입금
# 12    13     칭찬>삼성카드>심사/한도
# 13    14   칭찬>삼성카드>생활편의서비스
# 14    15     칭찬>삼성카드>상담/채널
# 15    16    칭찬>삼성카드>리스렌탈상품
# 16    17    칭찬>삼성카드>라이프서비스
# 17    18      칭찬>삼성카드>금융상품
# 18    19    칭찬>삼성카드>고객정보관리
# 19    20  칭찬>삼성카드>가맹점매출/승인
# 20    21     칭찬>삼성카드>가맹점대금
# 21    22     칭찬>삼성카드>가맹점계약
# 22    23           칭찬>삼성카드
# 23    24             칭찬>기타
# 24    25        불만>삼성카드>혜택
# 25    26    불만>삼성카드>할부금융상품
# 26    27   불만>삼성카드>커뮤니티서비스
# 27    28   불만>삼성카드>카드이용/결제
# 28    29      불만>삼성카드>카드상품
# 29    30      불만>삼성카드>청구입금
# 30    31     불만>삼성카드>심사/한도
# 31    32   불만>삼성카드>생활편의서비스
# 32    33     불만>삼성카드>상담/채널
# 33    34    불만>삼성카드>리스렌탈상품
# 34    35    불만>삼성카드>라이프서비스
# 35    36      불만>삼성카드>금융상품
# 36    37    불만>삼성카드>고객정보관리
# 37    38  불만>삼성카드>가맹점매출/승인
# 38    39     불만>삼성카드>가맹점대금
# 39    40     불만>삼성카드>가맹점계약
# 40    41           불만>삼성카드
# 41    42             불만>기타
# 42    43                중립
# 43    44                폐기

# %%
data.isnull().sum()
# Out:
# NO                        0
# NO2                       0
# 발화                        0
# 발화1                       0
# 발화1의 우선순위                 0
# 발화2                     968
# 발화2의 우선순위               968
# 발화3                     997
# 발화3의 우선순위               997
# 최종분류(우선순위 가장 높은것 선택)      0
# dtype: int64

# %%
len(data)
# Out:
# 1000

# %%
data.dropna(thresh = 4)
# Out:
#        NO    NO2                                                 발화  \
# 0       1   6438                                   상담직원과 빠른연결했슴좋겠어요
# 1       2   6850                                  안기다리고. 빨리상담되었음좋겠다
# 2       3   7294                                 너무 오래기다리고 상담이 늦어져요
# 3       4   9484                                상담직원과  통화가  매우  힘들다
# 4       5  10350                                   상담받으려면오래기다리는게불편함
# ..    ...    ...                                                ...
# 995  9958    103  카드분실된지 1분만에 카드를 통해서 연락받아 바로 찾았어요 잃어버린지도 몰랐는데 감...
# 996  9961      2             수시로 6개월무이자할부와 링크혜택이 다른카드와 구별되는 기능이 편리함
# 997  9962      4                               무이자할부 자주 많이 주셔서감사합니다
# 998  9963      5                                무이자혜택만족긴할부만족잘쓰고있습니다
# 999  9964      7                                 무이자 혜택이 많아 잘쓰고있어요.
#
#                 발화1  발화1의 우선순위         발화2  발화2의 우선순위  발화3  발화3의 우선순위  \
# 0    불만>고객서비스>상담시스템          5         NaN        NaN  NaN        NaN
# 1    불만>고객서비스>상담시스템          5         NaN        NaN  NaN        NaN
# 2    불만>고객서비스>상담시스템          5         NaN        NaN  NaN        NaN
# 3    불만>고객서비스>상담시스템          5         NaN        NaN  NaN        NaN
# 4    불만>고객서비스>상담시스템          5         NaN        NaN  NaN        NaN
# ..              ...        ...         ...        ...  ...        ...
# 995    칭찬>삼성카드>카드상품         11         NaN        NaN  NaN        NaN
# 996      칭찬>삼성카드>혜택          7  칭찬>삼성카드>혜택        7.0  NaN        NaN
# 997      칭찬>삼성카드>혜택          7         NaN        NaN  NaN        NaN
# 998      칭찬>삼성카드>혜택          7         NaN        NaN  NaN        NaN
# 999      칭찬>삼성카드>혜택          7         NaN        NaN  NaN        NaN
#
#     최종분류(우선순위 가장 높은것 선택)
# 0         불만>고객서비스>상담시스템
# 1         불만>고객서비스>상담시스템
# 2         불만>고객서비스>상담시스템
# 3         불만>고객서비스>상담시스템
# 4         불만>고객서비스>상담시스템
# ..                   ...
# 995         칭찬>삼성카드>카드상품
# 996           칭찬>삼성카드>혜택
# 997           칭찬>삼성카드>혜택
# 998           칭찬>삼성카드>혜택
# 999           칭찬>삼성카드>혜택
#
# [1000 rows x 10 columns]

# %%
for i in range(0, len(data['발화'])):
    data['발화'][i] = spacing(data['발화'][i])
# Out:
# <ipython-input-34-8c5c0c75d8b4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['발화'][i] = spacing(data['발화'][i])

# %%
data.head(15)
# Out:
#     NO    NO2                                        발화             발화1  \
# 0    1   6438                        상담직원과 빠른 연결했슴 좋겠어요  불만>고객서비스>상담시스템
# 1    2   6850                       안기다리고. 빨리 상담되었음 좋겠다  불만>고객서비스>상담시스템
# 2    3   7294                       너무 오래 기다리고 상담이 늦어져요  불만>고객서비스>상담시스템
# 3    4   9484                          상담직원과 통화가 매우 힘들다  불만>고객서비스>상담시스템
# 4    5  10350                      상담받으려면 오래 기다리는 게 불편함  불만>고객서비스>상담시스템
# 5    6  11435                 상담하려면 많이 기다려야 하는 게 불편합니다.  불만>고객서비스>상담시스템
# 6    7  12111                    상담원이 통화 중이라 많이 기다려야 해요  불만>고객서비스>상담시스템
# 7    8  12155                 상담직원과의 연결이 빠르게 연결되면 촣겠습니다  불만>고객서비스>상담시스템
# 8    9  12595                  ars상담직원 넘많이 기다려야 하는 불편해요   불만>삼성카드>상담/채널
# 9   10  12745                            상담원 통화가 너 믜 힘듬  불만>고객서비스>상담시스템
# 10  11  12748                  상담원과의 연결이 빨리 되었으면 감사 힘니다  불만>고객서비스>상담시스템
# 11  12  12751                           상담원이 영결이 많이 힘이듬  불만>고객서비스>상담시스템
# 12  13  12840  5번 질문에 대한 답변은 상담직원 연결되기까지 기다리는 것 말곤 없는 듯  불만>고객서비스>상담시스템
# 13  14  13164   상담을 하려면 좀 많이 기다려야 상담사분이 나오셔서 그게 좀 불편하네요  불만>고객서비스>상담시스템
# 14  15  15618                        Talk 상담이 다시 생겼으면..  불만>고객서비스>상담시스템
#
#     발화1의 우선순위             발화2  발화2의 우선순위  발화3  발화3의 우선순위 최종분류(우선순위 가장 높은것 선택)
# 0           5             NaN        NaN  NaN        NaN       불만>고객서비스>상담시스템
# 1           5             NaN        NaN  NaN        NaN       불만>고객서비스>상담시스템
# 2           5             NaN        NaN  NaN        NaN       불만>고객서비스>상담시스템
# 3           5             NaN        NaN  NaN        NaN       불만>고객서비스>상담시스템
# 4           5             NaN        NaN  NaN        NaN       불만>고객서비스>상담시스템
# 5           5             NaN        NaN  NaN        NaN       불만>고객서비스>상담시스템
# 6           5             NaN        NaN  NaN        NaN       불만>고객서비스>상담시스템
# 7           5             NaN        NaN  NaN        NaN       불만>고객서비스>상담시스템
# 8          33  불만>고객서비스>상담시스템        5.0  NaN        NaN       불만>고객서비스>상담시스템
# 9           5             NaN        NaN  NaN        NaN       불만>고객서비스>상담시스템
# 10          5             NaN        NaN  NaN        NaN       불만>고객서비스>상담시스템
# 11          5             NaN        NaN  NaN        NaN       불만>고객서비스>상담시스템
# 12          5             NaN        NaN  NaN        NaN       불만>고객서비스>상담시스템
# 13          5             NaN        NaN  NaN        NaN       불만>고객서비스>상담시스템
# 14          5             NaN        NaN  NaN        NaN       불만>고객서비스>상담시스템

# %%
print("내용의 최대 길이 : ", max(len(l) for l in data['발화'])) 
print("내용의 평균 길이 : ", sum(map(len, data['발화']))/ len(data['발화']))
plt.hist([len(s) for s in data['발화']], bins=50) 
plt.xlabel('length of Data')
plt.ylabel('number of Data')
plt.show()
# Out:
# 내용의 최대 길이 :  252
# 내용의 평균 길이 :  26.682

# %%
data.to_excel('발화내용 띄어쓰기 데이터.xlsx')
